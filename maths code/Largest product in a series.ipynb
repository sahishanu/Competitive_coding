# %%
"""
Approch: Sliding window
"""
def sliding(s,k):
    l=len(s)
    max_m=1
    for i in range(k):
        max_m*=int(s[i])
    new=max_m
    i=0
    j=i+k-1
    while(j+1<l):
        if(new==0 and s[j+1]!=0):
            new=1
            for x in range(i+1,j+2):
                new*=s[x]
        elif(s[j+1]==0):
            new=0
        else:
            new=(new*s[j+1])//s[i]
        if(new>max_m):
            max_m=new
        i+=1
        j+=1
    return(max_m)
s="..."
k=13
s=list(map(int,list(s)))
# print(s)
print(sliding(s,k))
# Out:
# 23514624000
